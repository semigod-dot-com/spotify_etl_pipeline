# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id="1b8bc780d59c42c8a6e009036cd08885",
    client_secret="7eed8aba12804843845a949d9cc1b770",
    redirect_uri="http://127.0.0.1:8888/callback/",
    scope="user-read-recently-played"
))

recent_tracks = sp.current_user_recently_played(limit=50)  
tracks_data = [{
    'played_at': item['played_at'],
    'track_name': item['track']['name'],
    'artist_name': item['track']['artists'][0]['name'],
    'album': item['track']['album']['name'],
    'release_date': item['track']['album']['release_date'],
    'duration_ms': item['track']['duration_ms'],
    'track_id': item['track']['id'],
    'track_uri': item['track']['uri']
} for item in recent_tracks['items']]

df = pd.DataFrame(tracks_data)
df.head()
# Out:
#                   played_at       track_name    artist_name  \
# 0  2025-06-09T18:08:43.074Z  MONTAGEM LADRAO          ATLXS
# 1  2025-06-09T18:08:42.227Z            watch  Billie Eilish
# 2  2025-06-09T15:10:25.372Z  FUNK UNIVERSO 2          Irokz
# 3  2025-06-09T15:08:31.501Z                8  Billie Eilish
# 4  2025-06-09T15:00:40.586Z          bad guy  Billie Eilish
#
#                                       album release_date  duration_ms  \
# 0                           MONTAGEM LADRAO   2025-02-05        75240
# 1                          dont smile at me   2017-12-22       177523
# 2                           FUNK UNIVERSO 2   2024-10-25       127058
# 3  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?   2019-03-29       173201
# 4  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?   2019-03-29       194087
#
#                  track_id                             track_uri
# 0  48WnIIBbnttcwUQ77MBoMI  spotify:track:48WnIIBbnttcwUQ77MBoMI
# 1  7eB1V5LvAdxCc7brfGhRRo  spotify:track:7eB1V5LvAdxCc7brfGhRRo
# 2  5a6RCqMaNpExBHNLzFqJff  spotify:track:5a6RCqMaNpExBHNLzFqJff
# 3  6X29iaaazwho3ab7GNue5r  spotify:track:6X29iaaazwho3ab7GNue5r
# 4  2Fxmhks0bxGSBdJ92vM42m  spotify:track:2Fxmhks0bxGSBdJ92vM42m

# %%
df.to_csv('recent_tracks.csv', index=False)
print("recent tracks data saved to 'recent_tracks.csv'")
# Out:
# recent tracks data saved to 'recent_tracks.csv'
